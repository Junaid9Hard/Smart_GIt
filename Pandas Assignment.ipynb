# %% [markdown]
# # Pandas Assignment.

# %% [markdown]
# ### 1. Create a data series with marks of students : 75, 80, 79, 60

# %%
import pandas as pd
from pandas import DataFrame,Series
Students_Marks = Series([75,80,79,60])
Students_Marks
# Out:
# 0    75
# 1    80
# 2    79
# 3    60
# dtype: int64

# %% [markdown]
# ### 2. Create a data frame with name of students, id and marks

# %%
Data_Frame = DataFrame({'Student Names':['Junaid','Ahmed' ,'Zayan','Saad'],'Student ID':[1101,1102,1103,1104],'Marks': Students_Marks})
Data_Frame
# Out:
#   Student Names  Student ID  Marks
# 0        Junaid        1101     75
# 1         Ahmed        1102     80
# 2         Zayan        1103     79
# 3          Saad        1104     60

# %% [markdown]
# ### 3. Now read the file 'data.csv' in panda

# %%
Read = pd.read_csv("Elec 18.csv")
Read
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %% [markdown]
# ### 4. What are the columns in the dataframe?

# %% [markdown]
# ### 5. Sort the data based on Marks obtained. Fill all the 'na' cells with 0

# %% [markdown]
# ### 6. Display the top 10 rows

# %% [markdown]
# ### 7. Display the last 10 rows

# %% [markdown]
# ### 8. Display only the odd rows

# %% [markdown]
# ### 9. Display only those students who got failed in examination

# %% [markdown]
# ### 10. Find out the basic statistical info about data

# %% [markdown]
# ### 11. How many students got A, B, C, F?

# %% [markdown]
# ### 12. What are the mean scores for students who got A, B, C, F?

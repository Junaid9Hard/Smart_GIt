# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series

# %%
person = pd.DataFrame({
    'name':['Junaid','Ahmed',"Salman","Zayan","Bilal"],
            'age': np.random.randint(1,40, size = [5]),
            'percent':np.random.randint(40,90, size = [5])})

# %%
person
# Out:
#      name  age  percent
# 0  Junaid   20       85
# 1   Ahmed   16       85
# 2  Salman   36       64
# 3   Zayan    5       64
# 4   Bilal   21       88

# %%
def Age(age):
    if age > 18:
        return "Adult"
    else:
        return "Non_Adult"

# %%
person['Value'] =  person['age'].apply(Age)

# %%
person
# Out:
#      name  age  percent      Value
# 0  Junaid   20       85      Adult
# 1   Ahmed   16       85  Non_Adult
# 2  Salman   36       64      Adult
# 3   Zayan    5       64  Non_Adult
# 4   Bilal   21       88      Adult

# %%
data = pd.read_csv('data_for_panda_exercise.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-939e8692d813> in <module>
# ----> 1 data = pd.read_csv('data_for_panda_exercise.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
data

# %%
data.head(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8eef6fbcd8a4> in <module>
# ----> 1 data.head(7)
#
# NameError: name 'data' is not defined

# %%
data.groupby(['Best of Assignments']).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2c76d6e7c00d> in <module>
# ----> 1 data.groupby(['Best of Assignments']).count()
#
# NameError: name 'data' is not defined

# %%
data.groupby(['Best of Assignments']).count()>8
# Out:
#                      Student Code  Degree  Student Name    Mid  Quiz 1  \
# Best of Assignments
# 0                           False   False         False  False   False
# 2                           False   False         False  False   False
# 5                           False   False         False  False   False
# 6                           False   False         False  False   False
# 7                           False   False         False  False   False
# 8                           False   False         False  False   False
# 9                            True    True          True   True    True
# 10                           True    True          True   True    True
# 11                          False   False         False  False   False
#
#                      Quiz 2  Best of Quizzes  Assignment 1  Assignment 2  \
# Best of Assignments
# 0                     False            False         False         False
# ...

# %%
data.groupby(['Quiz 1',"Quiz 2"]).count()
# Out:
#                Student Code  Degree  Student Name  Mid  Best of Quizzes  \
# Quiz 1 Quiz 2
# 4.0    2.0                1       1             1    1                1
#        4.0                1       1             1    1                1
# 5.0    2.0                2       2             2    2                2
#        4.0                1       1             1    1                1
#        5.0                1       1             1    1                1
#        6.0                2       2             2    2                2
# 6.0    6.0                2       2             2    2                2
# 7.0    1.0                1       1             1    1                1
#        2.0                1       1             1    1                1
#        4.0                1       1             1    1                1
#        5.0                3       3             3    3                3
#        6.0                4       4             4    4                4
# ...

# %%
data.Grade=='A'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40     True
# 41    False
# 42    False
# 43    False
# 44    False
# 45     True
# 46    False
# 47    False
# Name: Grade, dtype: bool

# %%
sum(data.Grade=='A')
# Out:
# 8

# %%
data[data.Total Sessional(50) > 5]
# Out:
#   File "<ipython-input-44-c584de99d538>", line 1
#     data[data.Total Sessional(50) > 5]
#                             ^
# SyntaxError: invalid syntax

# %%
data[(data.Grade=='A')&(data.Student Name.str.startswith('A'))]
# Out:
#   File "<ipython-input-46-568d6bfd1811>", line 1
#     data[(data.Grade=='A')&(data.Student Name.str.startswith('A'))]
#                                             ^
# SyntaxError: invalid syntax

# %%
data.iloc[5]   #use to check deatils from index
# Out:
# Student Code            022-14-110232
# Degree                         BS(CS)
# Student Name              Ameer Hamza
# Mid                                25
# Quiz 1                              9
# Quiz 2                              6
# Best of Quizzes                     9
# Assignment 1                        8
# Assignment 2                       10
# Best of Assignments                10
# Total Sessional (50)               44
# Final (50)                         27
# Total (100)                        71
# Grade                               B
# Name: 5, dtype: object

# %%
data.iloc[2]
# Out:
# Student Code            022-14-110585
# Degree                         BS(CS)
# Student Name             Afrah Zareen
# Mid                                18
# Quiz 1                              5
# Quiz 2                              2
# Best of Quizzes                     5
# Assignment 1                        8
# Assignment 2                       10
# Best of Assignments                10
# Total Sessional (50)               33
# Final (50)                         30
# Total (100)                        63
# Grade                               C
# Name: 2, dtype: object

# %%
data.Assignmets 2[3:8]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-68f88bcb9fc2> in <module>
# ----> 1 data.Assignmets_2[3:8]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Assignmets_2'

# %%
data[data.Student_Name=='Abdul Baist']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-427610a8e03c> in <module>
# ----> 1 data[data.Student_Name=='Abdul Baist']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Student_Name'

# %%
from fuzzywuzzy import fuzz as f
# Out:
# C:\Users\Junaidzayan\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
electdata = data
